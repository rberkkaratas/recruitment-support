# %%
from pathlib import Path
import pandas as pd

# Path to your parquet
p = Path("../data/intermediate/player_season_base.parquet")

# Load
df = pd.read_parquet(p)

# Optional: make pandas show more columns without truncation
pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 120)

# Preview
df.head()
# Out:
#                league season     team         player nation    pos  age  born  Playing_Time_MP  Playing_Time_Starts  \
# 0  ENG-Premier League   2425  Arsenal      Ben White    ENG     DF   26  1997               17                   13
# 1  ENG-Premier League   2425  Arsenal    Bukayo Saka    ENG  FW,MF   22  2001               25                   20
# 2  ENG-Premier League   2425  Arsenal     David Raya    ESP     GK   28  1995               38                   38
# 3  ENG-Premier League   2425  Arsenal    Declan Rice    ENG     MF   25  1999               35                   33
# 4  ENG-Premier League   2425  Arsenal  Ethan Nwaneri    ENG  FW,MF   17  2007               26                   11
#
#    Playing_Time_Min  Playing_Time_90s  Performance_Gls  Performance_Ast  Performance_G+A  Performance_G-PK  \
# 0              1198              13.3                0                2                2                 0
# ...

# %%
import pandas as pd
df = pd.read_csv("../data/exports/tableau/fact_shortlist.csv")

df.head(10)
# Out:
#                                   player_id  \
# 0  3c9f9b711ec0b9279543a8cb988a290b43a6f5bf
# 1  b2e2869d8a267248f3d546ed8298a4464aa1aae4
# 2  da02dd5e10e8799b1354003f6f9026c1d75f5819
# 3  bf637c89f682bf31c1d00b1cb3c7c4bb996f1be6
# 4  f2d8955ab51042440314a94dbc939f50af910d77
# 5  65535adfb4eed37a77112407e2089e2dddcef03f
# 6  f72bd2ea8d5db4e4983684186b222ffc3c733e2a
# 7  01aa30727d23733542f8cfce1677666789d52dda
# 8  102eff7fbe42221d59d3b4021418ac919c9bc579
# 9  e9d1746e9318730a6e6dcf2304d5cf7881d123db
#
#                                     team_id              league  season  \
# 0  2cb821a71d52a497722cb65cf17d794bdc6f6456  ENG-Premier League    2425
# 1  48b8fb813da0c253f6a1b03155b74429dd1d7ea6  ENG-Premier League    2425
# 2  48b8fb813da0c253f6a1b03155b74429dd1d7ea6  ENG-Premier League    2425
# 3  a75ee48342501c6998a54edfac1785e5ab59a9f2  ENG-Premier League    2425
# 4  1e03827ecad0e93b021a52ca51efe491c1afaf44  ENG-Premier League    2425
# ...
